# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=ywang password=Love520!")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
pwd
# Out:
# '/home/noma/Documents/OpenClass/Udacity/DEND/Udacity_DEND/SampleData/project_template'

# %%
ls
# Out:
# create_tables.py  etl_local.ipynb  __pycache__/  sql_queries.py
# etl.ipynb         etl.py           README.md     test.ipynb

# %%
song_files = get_files(filepath)

# %%
filepath = '../song_data'

# %%
song_files
# Out:
# ['/home/noma/Documents/OpenClass/Udacity/DEND/Udacity_DEND/SampleData/song_data/TRAAAAW128F429D538.json']

# %%
df = pd.read_json(song_files[0],lines=True)
df.head()
# Out:
#             artist_id  artist_latitude  artist_location  artist_longitude  \
# 0  ARD7TVE1187B99BFB1              NaN  California - LA               NaN
#
#   artist_name   duration  num_songs             song_id             title  \
# 0      Casual  218.93179          1  SOMZWCG12A8C13C480  I Didn't Mean To
#
#    year
# 0     0

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = df[['song_id','title','year','artist_id','duration']].values[0].tolist()
#song_data = tuple(song_data)
song_data
# Out:
# ['SOMZWCG12A8C13C480', "I Didn't Mean To", 0, 'ARD7TVE1187B99BFB1', 218.93179]

# %%
run create_tables.py

# %%
run sql_queries.py

# %%
song_table_insert
# Out:
# ' INSERT INTO song (song_id, title, year, artist_id, duration ) VALUES (%s, %s, %s, %s, %s)\n'

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = df[['artist_id','artist_name','artist_location','artist_latitude','artist_longitude']].values[0].tolist()
artist_data
# Out:
# ['ARD7TVE1187B99BFB1', 'Casual', 'California - LA', nan, nan]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files(filepath)

# %%
filepath = '../log_data'

# %%
log_files
# Out:
# ['/home/noma/Documents/OpenClass/Udacity/DEND/Udacity_DEND/SampleData/log_data/2018-11-01-events.json',
#  '/home/noma/Documents/OpenClass/Udacity/DEND/Udacity_DEND/SampleData/log_data/2018-11-06-events.json']

# %%
df = pd.read_json(log_files[1],lines=True)
df
# Out:
#                               artist       auth firstName gender  \
# 0                               None  Logged In     Adler      M
# 1                     Gustavo Cerati  Logged In     Adler      M
# 2                        Limp Bizkit  Logged In     Adler      M
# 3                               None  Logged In    Samuel      M
# 4                     Mikel Erentxun  Logged In    Samuel      M
# 5                        The Gerbils  Logged In    Martin      M
# 6                                AFI  Logged In    Martin      M
# 7                               None  Logged In    Jordan      F
# 8                      Lhasa De Sela  Logged In    Jordan      F
# 9                          J.J. Cale  Logged In    Jordan      F
# 10                         Brian Eno  Logged In    Jordan      F
# 11                      Hot Hot Heat  Logged In    Jordan      F
# 12                              None  Logged In      Lily      F
# 13                               ATB  Logged In      Ryan      M
# 14                              None  Logged In     Tegan      F
# 15       Mt. St. Helens Vietnam Band  Logged In      Ryan      M
# 16                             Becky  Logged In      Ryan      M
# 17                   Franz Ferdinand  Logged In      Ryan      M
# 18      Creedence Clearwater Revival  Logged In      Ryan      M
# 19                      Paul Stanley  Logged In     Tegan      F
# 20                             Benga  Logged In     Kevin      M
# 21                        Basshunter  Logged In     Kevin      M
# 22                     Kings Of Leon  Logged In     Kevin      M
# 23                        Slim Dusty  Logged In    Austin      M
# 24                              None  Logged In      Ryan      M
# 25                              Dido  Logged In   Celeste      F
# 26                         Lifehouse  Logged In   Celeste      F
# 27                   Gary U.S. Bonds  Logged In   Celeste      F
# 28               Throw Me The Statue  Logged In   Celeste      F
# 29                        Steely Dan  Logged In  Mohammad      M
# ..                               ...        ...       ...    ...
# 154                       Hank Penny  Logged In      Kate      F
# 155                 Carrie Underwood  Logged In      Kate      F
# 156                        Black Box  Logged In      Kate      F
# 157                       Cloud Cult  Logged In      Kate      F
# 158                          Cartola  Logged In      Kate      F
# 159                             None  Logged In      Kate      F
# 160                  Octopus Project  Logged In      Kate      F
# 161                       Peter Tosh  Logged In      Kate      F
# 162                     Alter Bridge  Logged In      Kate      F
# 163             Two Door Cinema Club  Logged In      Kate      F
# 164                   Ray LaMontagne  Logged In      Kate      F
# 165                        Lady GaGa  Logged In      Kate      F
# 166                        Colt Ford  Logged In      Kate      F
# 167                       Tracy Byrd  Logged In      Kate      F
# 168                        Brand New  Logged In      Kate      F
# 169     Creedence Clearwater Revival  Logged In      Kate      F
# 170               Earth_ Wind & Fire  Logged In      Kate      F
# 171                      Fleet Foxes  Logged In     Tegan      F
# 172                  be your own PET  Logged In      Kate      F
# 173                      The Killers  Logged In      Kate      F
# 174                        Roy Ayers  Logged In     Tegan      F
# 175                          Rihanna  Logged In      Kate      F
# 176                  Andres Calamaro  Logged In      Kate      F
# 177                      Blue States  Logged In      Kate      F
# 178                   The Black Keys  Logged In      Kate      F
# 179                           Staind  Logged In      Kate      F
# 180                     James Taylor  Logged In      Kate      F
# 181                             Moby  Logged In      Kate      F
# 182                        Girl Talk  Logged In      Kate      F
# 183  Sean Kingston and Justin Bieber  Logged In      Kate      F
#
#      itemInSession   lastName     length level  \
# 0                0    Barrera        NaN  free
# 1                1    Barrera  249.44281  free
# 2                2    Barrera  270.49751  free
# 3                0   Gonzalez        NaN  free
# 4                1   Gonzalez  178.83383  free
# 5                0    Johnson   27.01016  free
# 6                1    Johnson  190.45832  free
# 7                0      Hicks        NaN  free
# 8                1      Hicks  256.10404  free
# 9                2      Hicks  150.80444  free
# 10               3      Hicks  265.82159  free
# 11               4      Hicks  190.01424  free
# 12               0      Burns        NaN  free
# 13               0      Smith  209.26649  free
# 14               0     Levine        NaN  free
# 15               1      Smith  253.62240  free
# 16               2      Smith  245.62893  free
# 17               3      Smith  254.69342  free
# 18               4      Smith  230.94812  free
# 19               1     Levine  187.32363  free
# 20               0   Arellano  314.64444  free
# 21               1   Arellano  190.17098  free
# 22               2   Arellano  231.81016  free
# 23               0    Rosales  198.92200  free
# 24               0      Smith        NaN  free
# 25               0   Williams  235.57179  free
# 26               1   Williams  195.47383  free
# 27               2   Williams  243.25179  free
# 28               3   Williams  189.85751  free
# 29               0  Rodriguez  457.89995  free
# ..             ...        ...        ...   ...
# 154             60    Harrell  145.34485  paid
# 155             61    Harrell  225.20118  paid
# 156             62    Harrell  312.99873  paid
# 157             63    Harrell  213.31546  paid
# 158             64    Harrell  188.65587  paid
# 159             65    Harrell        NaN  paid
# 160             66    Harrell  422.16444  paid
# 161             67    Harrell  267.49342  paid
# 162             68    Harrell  286.35383  paid
# 163             69    Harrell  207.43791  paid
# 164             70    Harrell  236.59057  paid
# 165             71    Harrell  169.87383  paid
# 166             72    Harrell  170.84036  paid
# 167             73    Harrell  182.02077  paid
# 168             74    Harrell  386.74240  paid
# 169             75    Harrell  160.02567  paid
# 170             76    Harrell  280.47628  paid
# 171              0     Levine  208.03873  free
# 172             77    Harrell   66.87302  paid
# 173             78    Harrell  220.89098  paid
# 174              1     Levine  240.90077  free
# 175             79    Harrell  229.04118  paid
# 176             80    Harrell  144.58730  paid
# 177             81    Harrell  299.23220  paid
# 178             82    Harrell  161.85424  paid
# 179             83    Harrell  291.65669  paid
# 180             84    Harrell  253.12608  paid
# 181             85    Harrell  198.60853  paid
# 182             86    Harrell  170.73587  paid
# 183             87    Harrell  201.95220  paid
#
#                                     location method      page  registration  \
# 0      New York-Newark-Jersey City, NY-NJ-PA    GET      Home  1.540836e+12
# 1      New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1.540836e+12
# 2      New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1.540836e+12
# 3       Houston-The Woodlands-Sugar Land, TX    GET      Home  1.540493e+12
# 4       Houston-The Woodlands-Sugar Land, TX    PUT  NextSong  1.540493e+12
# 5    Minneapolis-St. Paul-Bloomington, MN-WI    PUT  NextSong  1.541082e+12
# 6    Minneapolis-St. Paul-Bloomington, MN-WI    PUT  NextSong  1.541082e+12
# 7                                Salinas, CA    GET      Home  1.540009e+12
# 8                                Salinas, CA    PUT  NextSong  1.540009e+12
# 9                                Salinas, CA    PUT  NextSong  1.540009e+12
# 10                               Salinas, CA    PUT  NextSong  1.540009e+12
# 11                               Salinas, CA    PUT  NextSong  1.540009e+12
# 12     New York-Newark-Jersey City, NY-NJ-PA    GET      Home  1.540621e+12
# 13        San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
# 14               Portland-South Portland, ME    GET      Home  1.540794e+12
# 15        San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
# 16        San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
# 17        San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
# 18        San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
# 19               Portland-South Portland, ME    PUT  NextSong  1.540794e+12
# 20                   Harrisburg-Carlisle, PA    PUT  NextSong  1.540007e+12
# 21                   Harrisburg-Carlisle, PA    PUT  NextSong  1.540007e+12
# 22                   Harrisburg-Carlisle, PA    PUT  NextSong  1.540007e+12
# 23     New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1.541060e+12
# 24        San Jose-Sunnyvale-Santa Clara, CA    GET      Home  1.541017e+12
# 25                         Klamath Falls, OR    PUT  NextSong  1.541078e+12
# 26                         Klamath Falls, OR    PUT  NextSong  1.541078e+12
# 27                         Klamath Falls, OR    PUT  NextSong  1.541078e+12
# 28                         Klamath Falls, OR    PUT  NextSong  1.541078e+12
# 29   Sacramento--Roseville--Arden-Arcade, CA    PUT  NextSong  1.540512e+12
# ..                                       ...    ...       ...           ...
# 154                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 155                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 156                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 157                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 158                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 159                 Lansing-East Lansing, MI    GET      Home  1.540473e+12
# 160                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 161                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 162                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 163                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 164                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 165                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 166                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 167                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 168                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 169                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 170                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 171              Portland-South Portland, ME    PUT  NextSong  1.540794e+12
# 172                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 173                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 174              Portland-South Portland, ME    PUT  NextSong  1.540794e+12
# 175                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 176                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 177                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 178                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 179                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 180                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 181                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 182                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 183                 Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
#
#      sessionId                                         song  status  \
# 0          248                                         None     200
# 1          248                               Uno Entre 1000     200
# 2          248                             Behind Blue Eyes     200
# 3          252                                         None     200
# 4          252                                 Frases Mudas     200
# 5          250                                        (iii)     200
# 6          250                              Girl's Not Grey     200
# 7          240                                         None     200
# 8          240                           De cara a la pared     200
# 9          240                                   Crazy Mama     200
# 10         240   An Ending (Ascent) (2005 Digital Remaster)     200
# 11         240             Soldier In A Box (Album Version)     200
# 12         287                                         None     200
# 13         278                             You're Not Alone     200
# 14         279                                         None     200
# 15         278                                A Year Or Two     200
# 16         278                                       Kimi e     200
# 17         278                                    This Fire     200
# 18         278                          It's Just A Thought     200
# 19         279                                  Live To Win     200
# 20         191                                     Pleasure     200
# 21         191                                          Why     200
# 22         191                                 Use Somebody     200
# 23         300                              Long Black Road     200
# 24         306                                         None     200
# 25         215                                 I'm No Angel     200
# 26         215                 You And Me (Wedding Version)     200
# 27         215                                     Angelyne     200
# 28         215                                       Noises     200
# 29         206                                 Deacon Blues     200
# ..         ...                                          ...     ...
# 154        293                    No Muss No Fuss No Bother     200
# 155        293                                     So Small     200
# 156        293                                      Fantasy     200
# 157        293                      Running With the Wolves     200
# 158        293                      Verde Que Te Quero Rosa     200
# 159        293                                         None     200
# 160        293                            The Way Things Go     200
# 161        293  Recruiting Soldiers (2002 Digital Remaster)     200
# 162        293                              Down To My Last     200
# 163        293                                Costume Party     200
# 164        293                      Trouble (Album Version)     200
# 165        293                                      Fashion     200
# 166        293                            Huntin' The World     200
# 167        293                             Watermelon Crawl     200
# 168        293                                         Noro     200
# 169        293                  Have You Ever Seen The Rain     200
# 170        293                                    Pure Gold     200
# 171        307                  Tiger Mountain Peasant Song     200
# 172        293                                  Food Fight!     200
# 173        293                          When You Were Young     200
# 174        307                                    Searching     200
# 175        293                                   Take A Bow     200
# 176        293                          El Novio Del Olvido     200
# 177        293                                    Walkabout     200
# 178        293                          Act Nice and Gentle     200
# 179        293                Outside (Original LP Version)     200
# 180        293                             Sweet Baby James     200
# 181        293                         Time's Up (Dust Mix)     200
# 182        293                                      Hold up     200
# 183        293                                 Eenie Meenie     200
#
#                 ts                                          userAgent userId
# 0    1541470364796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...    100
# 1    1541470383796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...    100
# 2    1541470632796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...    100
# 3    1541473967796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     61
# 4    1541474048796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     61
# 5    1541480171796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     55
# 6    1541480198796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     55
# 7    1541480984796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     37
# 8    1541481077796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     37
# 9    1541481333796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     37
# 10   1541481483796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     37
# 11   1541481748796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     37
# 12   1541483351796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     32
# 13   1541484351796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 14   1541484363796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 15   1541484560796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 16   1541484813796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 17   1541485058796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 18   1541485312796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 19   1541485351796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 20   1541489492796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 21   1541489806796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 22   1541489996796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 23   1541494159796  Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20...     12
# 24   1541496567796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 25   1541498691796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 26   1541498926796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 27   1541499121796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 28   1541499364796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 29   1541505185796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     88
# ..             ...                                                ...    ...
# 154  1541542796796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 155  1541542941796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 156  1541543166796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 157  1541543478796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 158  1541543691796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 159  1541543762796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 160  1541543879796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 161  1541544301796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 162  1541544568796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 163  1541544854796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 164  1541545061796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 165  1541545297796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 166  1541545466796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 167  1541545636796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 168  1541545818796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 169  1541546204796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 170  1541546364796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 171  1541546584796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 172  1541546644796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 173  1541546710796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 174  1541546792796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 175  1541546930796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 176  1541547159796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 177  1541547303796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 178  1541547602796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 179  1541547763796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 180  1541548054796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 181  1541548307796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 182  1541548505796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
# 183  1541548675796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97
#
# [184 rows x 18 columns]

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = df[df.page == 'NextSong']
df.head()
# Out:
#            artist       auth firstName gender  itemInSession  lastName  \
# 1  Gustavo Cerati  Logged In     Adler      M              1   Barrera
# 2     Limp Bizkit  Logged In     Adler      M              2   Barrera
# 4  Mikel Erentxun  Logged In    Samuel      M              1  Gonzalez
# 5     The Gerbils  Logged In    Martin      M              0   Johnson
# 6             AFI  Logged In    Martin      M              1   Johnson
#
#       length level                                 location method      page  \
# 1  249.44281  free    New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 2  270.49751  free    New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 4  178.83383  free     Houston-The Woodlands-Sugar Land, TX    PUT  NextSong
# 5   27.01016  free  Minneapolis-St. Paul-Bloomington, MN-WI    PUT  NextSong
# 6  190.45832  free  Minneapolis-St. Paul-Bloomington, MN-WI    PUT  NextSong
#
#    registration  sessionId              song  status             ts  \
# 1  1.540836e+12        248    Uno Entre 1000     200  1541470383796
# 2  1.540836e+12        248  Behind Blue Eyes     200  1541470632796
# 4  1.540493e+12        252      Frases Mudas     200  1541474048796
# 5  1.541082e+12        250             (iii)     200  1541480171796
# 6  1.541082e+12        250   Girl's Not Grey     200  1541480198796
#
#                                            userAgent userId
# 1  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...    100
# 2  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...    100
# 4  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     61
# 5  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     55
# 6  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     55

# %%
t = (pd.Timestamp(i) for i in df.ts.values)
#t = [(i,i.hour,i.day,i.weekofyear,i.month,i.year,i.dayofweek) for i in t]
time_data = [(i,i.hour,i.day,i.weekofyear,i.month,i.year,i.dayofweek) for i in t]

# %%
column_labels = ('timestamp','hour','day','week of year','month','year','weekday')

# %%
time_df = pd.DataFrame(time_data,columns=column_labels)
time_df.head(10)
# Out:
#                       timestamp  hour  day  week of year  month  year  weekday
# 0 1970-01-01 00:25:41.470383796     0    1             1      1  1970        3
# 1 1970-01-01 00:25:41.470632796     0    1             1      1  1970        3
# 2 1970-01-01 00:25:41.474048796     0    1             1      1  1970        3
# 3 1970-01-01 00:25:41.480171796     0    1             1      1  1970        3
# 4 1970-01-01 00:25:41.480198796     0    1             1      1  1970        3
# 5 1970-01-01 00:25:41.481077796     0    1             1      1  1970        3
# 6 1970-01-01 00:25:41.481333796     0    1             1      1  1970        3
# 7 1970-01-01 00:25:41.481483796     0    1             1      1  1970        3
# 8 1970-01-01 00:25:41.481748796     0    1             1      1  1970        3
# 9 1970-01-01 00:25:41.484351796     0    1             1      1  1970        3

# %%
for i, row in time_df.iterrows():
    print (list(row))
# Out:
# [Timestamp('1970-01-01 00:25:41.470383796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.470632796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.474048796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.480171796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.480198796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.481077796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.481333796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.481483796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.481748796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.484351796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.484560796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.484813796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.485058796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.485312796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.485351796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.489492796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.489806796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.489996796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.494159796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.498691796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.498926796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.499121796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.499364796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.505185796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.509129796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.509320796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.512300796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.515050796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.516147796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.516365796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.516676796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.516923796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.519555796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.519718796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.519780796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.519910796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.520095796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.520220796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.520284796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.520332796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.520410796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.520546796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.520628796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.520705796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.520869796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.520890796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.520927796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.521044796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.521083796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.521115796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.521243796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.521404796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.521633796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.521827796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.521974796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.522071796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.522295796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.522465796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.522696796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.525975796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.526197796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.526392796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.527887796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.528124796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.528286796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.528607796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.528875796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.529053796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.529271796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.529551796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.529811796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.530163796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.530317796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.530372796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.530600796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.530722796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.531058796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.531243796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.531461796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.531693796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.532041796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.532254796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.532490796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.532629796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.532809796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.533188796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.533370796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.533691796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.534023796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.534330796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.534550796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.534745796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.534937796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.535131796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.535377796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.535582796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.535711796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.535911796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.535943796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.536084796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.536304796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.536313796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.536673796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.536872796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.537126796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.537393796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.537680796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.537942796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.538136796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.538443796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.538727796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.538940796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.539531796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.540186796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.540422796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.540527796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.540728796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.541074796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.541309796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.541378796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.541629796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.541666796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.541893796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.542292796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.542545796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.542796796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.542941796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.543166796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.543478796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.543691796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.543879796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.544301796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.544568796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.544854796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.545061796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.545297796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.545466796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.545636796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.545818796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.546204796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.546364796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.546584796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.546644796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.546710796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.546792796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.546930796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.547159796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.547303796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.547602796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.547763796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.548054796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.548307796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.548505796'), 0, 1, 1, 1, 1970, 3]
# [Timestamp('1970-01-01 00:25:41.548675796'), 0, 1, 1, 1, 1970, 3]

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
df.head()
# Out:
#            artist       auth firstName gender  itemInSession  lastName  \
# 1  Gustavo Cerati  Logged In     Adler      M              1   Barrera
# 2     Limp Bizkit  Logged In     Adler      M              2   Barrera
# 4  Mikel Erentxun  Logged In    Samuel      M              1  Gonzalez
# 5     The Gerbils  Logged In    Martin      M              0   Johnson
# 6             AFI  Logged In    Martin      M              1   Johnson
#
#       length level                                 location method      page  \
# 1  249.44281  free    New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 2  270.49751  free    New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 4  178.83383  free     Houston-The Woodlands-Sugar Land, TX    PUT  NextSong
# 5   27.01016  free  Minneapolis-St. Paul-Bloomington, MN-WI    PUT  NextSong
# 6  190.45832  free  Minneapolis-St. Paul-Bloomington, MN-WI    PUT  NextSong
#
#    registration  sessionId              song  status             ts  \
# 1  1.540836e+12        248    Uno Entre 1000     200  1541470383796
# 2  1.540836e+12        248  Behind Blue Eyes     200  1541470632796
# 4  1.540493e+12        252      Frases Mudas     200  1541474048796
# 5  1.541082e+12        250             (iii)     200  1541480171796
# 6  1.541082e+12        250   Girl's Not Grey     200  1541480198796
#
#                                            userAgent userId
# 1  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...    100
# 2  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...    100
# 4  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     61
# 5  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     55
# 6  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     55

# %%
user_df = df[['userId','firstName','lastName','gender','level']]
user_df.head()
# Out:
#   userId firstName  lastName gender level
# 1    100     Adler   Barrera      M  free
# 2    100     Adler   Barrera      M  free
# 4     61    Samuel  Gonzalez      M  free
# 5     55    Martin   Johnson      M  free
# 6     55    Martin   Johnson      M  free

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
df.head(10)
# Out:
#             artist       auth firstName gender  itemInSession  lastName  \
# 1   Gustavo Cerati  Logged In     Adler      M              1   Barrera
# 2      Limp Bizkit  Logged In     Adler      M              2   Barrera
# 4   Mikel Erentxun  Logged In    Samuel      M              1  Gonzalez
# 5      The Gerbils  Logged In    Martin      M              0   Johnson
# 6              AFI  Logged In    Martin      M              1   Johnson
# 8    Lhasa De Sela  Logged In    Jordan      F              1     Hicks
# 9        J.J. Cale  Logged In    Jordan      F              2     Hicks
# 10       Brian Eno  Logged In    Jordan      F              3     Hicks
# 11    Hot Hot Heat  Logged In    Jordan      F              4     Hicks
# 13             ATB  Logged In      Ryan      M              0     Smith
#
#        length level                                 location method      page  \
# 1   249.44281  free    New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 2   270.49751  free    New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 4   178.83383  free     Houston-The Woodlands-Sugar Land, TX    PUT  NextSong
# 5    27.01016  free  Minneapolis-St. Paul-Bloomington, MN-WI    PUT  NextSong
# 6   190.45832  free  Minneapolis-St. Paul-Bloomington, MN-WI    PUT  NextSong
# 8   256.10404  free                              Salinas, CA    PUT  NextSong
# 9   150.80444  free                              Salinas, CA    PUT  NextSong
# 10  265.82159  free                              Salinas, CA    PUT  NextSong
# 11  190.01424  free                              Salinas, CA    PUT  NextSong
# 13  209.26649  free       San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
#
#     registration  sessionId                                        song  \
# 1   1.540836e+12        248                              Uno Entre 1000
# 2   1.540836e+12        248                            Behind Blue Eyes
# 4   1.540493e+12        252                                Frases Mudas
# 5   1.541082e+12        250                                       (iii)
# 6   1.541082e+12        250                             Girl's Not Grey
# 8   1.540009e+12        240                          De cara a la pared
# 9   1.540009e+12        240                                  Crazy Mama
# 10  1.540009e+12        240  An Ending (Ascent) (2005 Digital Remaster)
# 11  1.540009e+12        240            Soldier In A Box (Album Version)
# 13  1.541017e+12        278                            You're Not Alone
#
#     status             ts                                          userAgent  \
# 1      200  1541470383796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 2      200  1541470632796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4      200  1541474048796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 5      200  1541480171796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 6      200  1541480198796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 8      200  1541481077796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 9      200  1541481333796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 10     200  1541481483796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 11     200  1541481748796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 13     200  1541484351796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
#
#    userId
# 1     100
# 2     100
# 4      61
# 5      55
# 6      55
# 8      37
# 9      37
# 10     37
# 11     37
# 13     26

# %%
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    results = cur.execute(song_select, (row.song, row.artist, row.length))
    songid, artistid = results if results else None, None

    #insert songplay record
    songplay_data = (songid,pd.Timestamp(row['ts']),row['userId'],row['level'],artistid,row['sessionId'],row['location'],row['userAgent'])
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.

# %%
run create_tables.py
# Out:
# ---------------------------------------------
# ObjectInUse Traceback (most recent call last)
# ~/Documents/OpenClass/Udacity/DEND/Udacity_DEND/SampleData/project_template/create_tables.py in <module>
#      50
#      51 if __name__ == "__main__":
# ---> 52     main()
#
# ~/Documents/OpenClass/Udacity/DEND/Udacity_DEND/SampleData/project_template/create_tables.py in main()
#      36
#      37 def main():
# ---> 38     cur, conn = create_database()
#      39     try:
#      40
#
# ~/Documents/OpenClass/Udacity/DEND/Udacity_DEND/SampleData/project_template/create_tables.py in create_database()
#      10
#      11     # create sparkify database with UTF8 encoding
# ---> 12     cur.execute("DROP DATABASE IF EXISTS sparkifydb")
#      13     cur.execute("CREATE DATABASE sparkifydb WITH ENCODING 'utf8' TEMPLATE template0")
#      14
#
# ObjectInUse: database "sparkifydb" is being accessed by other users
# DETAIL:  There are 4 other sessions using the database.
